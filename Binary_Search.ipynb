# %% [markdown]
# #Binary Search
# * Works on only sorted array.
# *

# %%
def binary_search(arr,low,high,item):
  if low <= high:
    mid = (low + high) // 2

    if arr[mid]  == item:
      return mid
    elif arr[mid] > item:
      return binary_search(arr,low,mid-1,item)
    else:
      return binary_search(arr,mid+1,high,item)
  else:
    return 'Not found'

# %%
arr = [1,4,5,2,5,6,4,6,9]

# %%
binary_search(arr,0,len(arr),1)

# %%
def is_sorted(arr):
  sorted = True

  for i in range(len(arr) - 1):
    if arr[i] > arr[i+1]:
      sorted = False
  return sorted

# %%
arr = [1,2,3,9,5,6]
is_sorted(arr)
# Out:
# False

# %% [markdown]
# #Monkey Sort
# * If we tell monkey to sort cards
# * The monkey will throws all cards in the air and then pick the cards then check if cards get sorted it returns sorted arr else monkey do this step untill the cards will get sorted.
# * Time Complexity - infinity (worst case)

# %%
#Moneky sort

import random
import time


def moneky_sort(arr):

  while not is_sorted(arr):

    random.shuffle(arr)
    print(arr)
  print(arr)

# %%
moneky_sort([23,11,47,67,61])
# Out:
# [61, 67, 11, 47, 23]
# [23, 47, 11, 67, 61]
# [47, 11, 23, 61, 67]
# [61, 11, 67, 47, 23]
# [11, 47, 61, 67, 23]
# [23, 61, 67, 47, 11]
# [47, 67, 61, 11, 23]
# [67, 61, 47, 23, 11]
# [61, 47, 23, 11, 67]
# [11, 67, 23, 47, 61]
# [67, 61, 23, 11, 47]
# [67, 23, 61, 47, 11]
# [47, 61, 11, 67, 23]
# [23, 67, 11, 61, 47]
# [61, 47, 11, 23, 67]
# [23, 61, 67, 11, 47]
# [47, 67, 11, 61, 23]
# [23, 67, 11, 61, 47]
# [67, 23, 61, 11, 47]
# [47, 67, 61, 23, 11]
# [23, 11, 47, 61, 67]
# [47, 67, 11, 23, 61]
# [11, 61, 67, 23, 47]
# [23, 67, 47, 61, 11]
# [47, 11, 61, 67, 23]
# [67, 47, 23, 11, 61]
# [67, 47, 11, 23, 61]
# [23, 67, 11, 61, 47]
# [67, 11, 47, 23, 61]
# [61, 47, 67, 11, 23]
# [23, 11, 61, 47, 67]
# [11, 47, 23, 67, 61]
# [61, 11, 47, 23, 67]
# [23, 67, 61, 11, 47]
# [67, 23, 11, 47, 61]
# [67, 47, 11, 61, 23]
# [61, 11, 47, 23, 67]
# [11, 23, 67, 61, 47]
# [47, 67, 11, 61, 23]
# [11, 61, 47, 23, 67]
# [23, 47, 61, 67, 11]
# [61, 23, 47, 11, 67]
# [67, 47, 23, 61, 11]
# ...

# %% [markdown]
# #Sleep Sort
# - It is a joke sorting alorithm where it sort the elements after a time interval(time interval of element)
# - like [2,4,5,6,1] is arr then it sorts in 2+4+5+6+1 seconds and gives output [1,2,4,5,6]
